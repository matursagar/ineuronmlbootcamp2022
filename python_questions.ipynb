# %% [markdown]
# ### Assignment 13/12/2022

# %% [markdown]
# * WAP to accept two numbers from the user and display their sum

# %%
n1 = int(input("Enter the first number "))
n2 = int(input("Enter the second number "))

print(n1 + n2)
# Out:
# 14

# %% [markdown]
# * WAP to accept radius of a Circle from the user and calculate area and circumference

# %%
radius = float(input('Enter the radius of the circle'))
#Area of the circle
area = 3.14 * (radius ** 2)
#Circumference of the circle
circumference = 2 * 3.14 * radius

print("Area of the circle is {} and the circumference of the circle is {}".format(area,circumference))
# Out:
# Area of the circle is 78.5 and the circumference of the circle is 31.400000000000002

# %% [markdown]
# ●	WAP to accept roll number , grade and percentage as input from the user and display it back

# %%
r_num = input("Enter your roll number: ")
grade = input("Enter your grade: ")
percentage = input("Enter your percentage: ")
print("Roll number: {}, grade: {}, percentage: {}".format(r_num, grade, percentage))
# Out:
# Roll number: 24, grade: B, percentage: 64

# %% [markdown]
# ●	Write a program that asks the user to enter his/her name and age. Print out a message , displaying the user’s name along with the year in which they will turn 100 years old.

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
year = (2023 - age) + 100
print("{} will turn 100 in the year {}".format(name, year))
# Out:
# Sagar will turn 100 in the year 2090

# %% [markdown]
# ●	Write a program that asks the user to input 2 integers and adds them . Accept both the numbers in a single line only

# %%
x= input("Enter two integers: ")
a,b = x.split()
print(int(a) + int(b))
# Out:
# 31

# %% [markdown]
# ●	Write a Python program which accepts the user's first and last name and print them in reverse order with a space between them.

# %%
f_name = input("Enter your first name: ")
l_name = input("Enter your last name: ")
name = f_name + " " + l_name
print(name[::-1])
# Out:
# rutam ragas

# %% [markdown]
# ### Assignment 15/12/2022

# %% [markdown]
# ●	WAP to accept an integer from the user and check whether it is an even or odd

# %%
num = int(input("Enter an integer"))
if num % 2 ==0:
    print("%d is even" %num)
else:
    print("%d is odd" %num)
# Out:
# 7 is odd

# %% [markdown]
# ●	WAP to accept a character from the user and check whether it is a capital letter or small letter. Assume user will input only alphabets

# %%
chr = input("Enter a character")
if chr.isupper()==True:
    print("The character '{}' is in upper case.".format(chr))
else:
    print("The character '{}' is in lower case.".format(chr))
# Out:
# The character 'S' is in upper case.

# %% [markdown]
# ●	WAP to accept a character from the user and check whether it is a capital letter or small letter or a digit or some special symbol

# %%
chr = input("Enter a character or a digit or a special symbol: ")
if chr.isalpha()==True:
    if chr.isupper()==True:
        print("{} is uppercase".format(chr))
    else:
        print("{} is lowercase".format(chr))
elif chr.isdigit()==True:
    print("{} is a digit".format(chr))
else:
    print("{} is a special symbol".format(chr))
# Out:
# & is a special symbol

# %% [markdown]
# ●	WAP to accept 3 integers from the user and without using any logical operator and cascading of relational operators , find out the greatest number amongst them

# %%
num1 = int(input("Enter first number"))
num2 = int(input("Enter second number"))
num3 = int(input("Enter third number"))
if num1 > num2:
    if num1 > num3:
        print(str(num1) + " is the greatest number")
elif num2 > num3:
    print(str(num2) + " is the greatest number")
else:
    print(str(num3) + " is the greatest number")
# Out:
# 56 is the greatest number

# %% [markdown]
# ●	WAP to accept a year from the user and check whether it is a leap year or not.
# An year is a leap year if:
# It is exactly divisible by 4 and at the same time not
# divisible by 100
# OR
# It is divisible by 400
# For example:
# 2017 is not a leap year
# 2012 is a leap year
# 1900 is a not leap year
# 2000 is a leap year

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or year % 400 == 0:
    print("{} is a leap year".format(year))
else:
    print("{} is not a leap year".format(year))
# Out:
# 2016 is a leap year

# %% [markdown]
# ●	You have to develop a number guessing game. Following are the steps needed:
#
# 	1. At first , the program will generate a random integer secretly.
#
# 	2. Now it will ask the user to guess that number .
#
# 	3. If the user guessed it correctly then the program prints “Congratulations! You guessed it right” .
#
# 	4. But if the number guessed by the user is larger than the secret number then program should print “Number too large” and , if the number guessed by the user is smaller than the secret number then the program should print “Number too small”
#
# 	5. This should continue until the user guesses the number correctly or quits .
#
# 	6. If the user wants to quit in between he will have to type 0 or negative number

# %%
import random
a = random.randint(0, 100)
while True:
    guess = int(input("Enter a number"))
    if guess <=0:
        break
    if guess == a:
        print("Congratulations! You guessed it right")
    elif guess > a:
        print("Number too large")
    else:
        print("Number too small")
# Out:
# Number too large
# Number too large
# Number too large
# Number too small
# Number too large
# Number too large
# Number too large
# Congratulations! You guessed it right
# Number too small
# Congratulations! You guessed it right

# %% [markdown]
# ●	Write a program to accept a string from the user and display it vertically but don’t display the vowels in it.

# %%
name = input("Enter a string")
for i in name:
    if i in 'aeiouAEIOU':
        pass
    else:
        print(i)
# Out:
# S
# g
# r
#
# M
# t
# r

# %% [markdown]
# ●	Write a program to continuously accept integers from the user until the user types 0 and as soon as 0 is entered display sum of all the nos entered before 0.
#
# Note:Modify the previous code so that if the user inputs a negative integer , your program should ignore it .

# %%
total = 0
while True:
    num = int(input("Enter a number"))
    if num == 0:
        break
    elif num < 0:
        continue
    else:
        total = total + num
print("Sum of the number is " + str(total))
# Out:
# Sum of the number is 11

# %% [markdown]
# ●	Write a program using a for loop to accept a string from the user and display it vertically but don’t display the vowels in it.

# %% [markdown]
# ●	Write a program to accept an integer from the user and display the sum of all the numbers from 1 to that number.

# %%
num = int(input("Enter a number"))
sum = 0
for i in range(1, num+1):
    sum = sum + i
print(sum)
# Out:
# 15

# %% [markdown]
# ●	Write a program to accept an integer from the user and calculate its factorial

# %%
num = int(input("Enter a number"))
fact = 1
for i in range(num, 0, -1):
    fact = fact * i
print("factorial of {} is {}".format(num, fact))
# Out:
# factorial of 5 is 120

# %% [markdown]
# ●	Write a program to print the following pattern
#
# ![image.png](attachment:image.png)

# %%
for i in range(1, 5):
    for j in range(1, 4):
        print("*", end="")
    print()
# Out:
# ***
# ***
# ***
# ***

# %% [markdown]
# ●	Write a program to print the following pattern
#
# ![image.png](attachment:image.png)

# %%
for i in range(1, 5):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# ●	Write a program to print the following pattern
#
# ![image.png](attachment:image.png)

# %%
for i in range(5, 0, -1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ●	Write a program to accept an integer from the user and display all the numbers from 1 to that number. Repeat the process until the user enters 0.

# %%
num = int(input("Enter a number"))
sum=0
for i in range(1, num+1):
    print("The number is {}".format(i))
    sum += i
print("The sum is {}".format(sum))
# Out:
# The number is 1
# The number is 2
# The number is 3
# The number is 4
# The number is 5
# The sum is 15
